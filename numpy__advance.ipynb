# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhangi942/workshop/blob/main/numpy__advance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# speed
# list
a = [i for i in range(10000000)]
b = [i for i in range(10000000,20000000)]

c = []
import time

start = time.time()
for i in range(len(a)):
  c.append(a[i] + b[i])
print(time.time()-start)
# Out:
# 7.602646112442017

# %%
# numpy
import numpy as np
a = np.arange(10000000)
b = np.arange(10000000,20000000)

start = time.time()
c = a + b
print(time.time()-start)
# Out:
# 0.09431838989257812

# %%
import numpy as np

# %%
a=np.arange(3)
b=5

print(a)
print(b)

print(a+b)
# Out:
# [0 1 2]
# 5
# [5 6 7]

# %%
.02/0.042
# Out:
# 0.47619047619047616

# %%
nn = np.arange(-10,10)
def cube(a)
  return a*
  +

# %% [markdown]
# ##Broadcasting

# %%
a = np.arange(3)
b = 5

print(a)
print(b)

print(a+b)
# Out:
# [0 1 2]
# 5
# [5 6 7]

# %%
# Mathematical function
a = np.arange(10)
np.sin(a)
# Out:
# array([ 0.        ,  0.84147098,  0.90929743,  0.14112001, -0.7568025 ,
#        -0.95892427, -0.2794155 ,  0.6569866 ,  0.98935825,  0.41211849])

# %%
a3=np.array([1,2,3])

# %%
def square(a):
  return a*a

square(a3)
# Out:
# array([1, 4, 9])

# %% [markdown]
# ##Nan - Not a number / Missing values

# %%
# Working with missing values -> np.nan
a1 = np.array([1,2,3,4,np.nan,6]) # always make the whole array elements a float object
a1
# Out:
# array([ 1.,  2.,  3.,  4., nan,  6.])

# %%
a1[~np.isnan(a1)]
# Out:
# array([1., 2., 3., 4., 6.])

# %%
a = np.array([1,2,3,4,'nan',6])
a
# Out:
# array(['1', '2', '3', '4', 'nan', '6'], dtype='<U21')

# %% [markdown]
# ##Plotting graphs

# %%
# plotting a 2D plot
# x = y
import matplotlib.pyplot as plt

x = np.linspace(-10,10,100)
y = x

plt.plot(x,y)

# %%
def square(a):
  return a*a

g = np.arange(15)
squared_g = square(g)
print(squared_g)
plt.plot(g,squared_g)
# Out:
# [  0   1   4   9  16  25  36  49  64  81 100 121 144 169 196]

# %%
# y = sin(x)
x = np.linspace(-10,10,100)
y = np.sin(x)

plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0, 2*np.pi, 0.1)
x = 16 * np.sin(t)**3
y = 13 * np.cos(t) - 5 * np.cos(2*t) - 2 * np.cos(3*t) - np.cos(4*t)

plt.plot(x, y, color='red')
plt.title('Heart Shape')
plt.axis('equal')
plt.axis('on')
plt.show()

# %%
 #sigmoid
x = np.linspace(-10,10,100)
y = 1/(1+np.exp(-x))

plt.plot(x,y)

# %% [markdown]
# ##Proof of Numpy cant add elements in the original array it always makes a new copy

# %%
d = np.array([1,8,3,0])
print(id(d))
print(id(np.append(d,10)))
print(d)
print(id(d))
# Out:
# 135960891543728
# 135960891047536
# [1 8 3 0]
# 135960891543728

# %% [markdown]
# ##Numpy Functions
